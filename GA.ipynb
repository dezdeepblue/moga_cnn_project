# %% [markdown]
# <a href="https://colab.research.google.com/github/dezdeepblue/moga_cnn_project/blob/main/GA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !cd drive/MyDrive && mkdir GA && cd GA && git clone https://github.com/dezdeepblue/moga_cnn_project.git
# !cd moga_cnn_project
# !pip install -r drive/MyDrive/GA/moga_cnn_project/requirements.txt
# !cd drive/MyDrive/GA/moga_cnn_project/ && make full-cuda

# %%
# !pip install -r drive/MyDrive/GA/moga_cnn_project/requirements.txt
# !cd drive/MyDrive/GA/moga_cnn_project/ && make budget5-cuda
# !cd drive/MyDrive/GA/moga_cnn_project/ && make budget15-cuda
# Out:
# ...
# python -m src.pipeline --device cuda --results-dir results_budget5_cuda --pop-size 24 --ngen 8 --eval-epochs 5 --num-seeds 3 --transfer-dataset cifar100 --retrain-epochs 50 --retrain-seeds 3 --copy-to-report
# [PIPELINE] Starting run | seeds=[0, 1, 2] | pop=24 | ngen=8 | eval_epochs=5
# [PIPELINE] Stage 1/7: Running NSGA-II search
# [RUN_ALL] Running NSGA-II for seed 0
# [NSGA2] Seed=0 | population=24 | generations=8 | total evaluations=216
# [NSGA2] Initial population evaluation: [..............................] 0/216 (  0.0%)
# [DATA] Preparing CIFAR-10 dataset (download may take time on first run)...
# [DATA] CIFAR-10 ready | train=45000 | val=5000 | batch_size=128
# [NSGA2] seed0 init ind 1/24 | training started
# [TRAIN] seed0 init ind 1/24 | epoch 1/5 | batch 352/352
# [TRAIN] seed0 init ind 1/24 | epoch 2/5 | batch 352/352
# [TRAIN] seed0 init ind 1/24 | epoch 3/5 | batch 352/352
# [TRAIN] seed0 init ind 1/24 | epoch 4/5 | batch 352/352
# ...

# %%
# !pip install -r drive/MyDrive/GA/moga_cnn_project/requirements.txt
# !cd drive/MyDrive/GA/moga_cnn_project/ && make report-tex
# !cd drive/MyDrive/GA/moga_cnn_project/ && make report-pdf
